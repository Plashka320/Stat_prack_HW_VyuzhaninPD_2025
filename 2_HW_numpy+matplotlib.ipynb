# %% [markdown]
# <a href="https://colab.research.google.com/github/Plashka320/Stat_prack_HW_VyuzhaninPD_2025/blob/main/2_HW_numpy%2Bmatplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem 1

# %% [markdown]
# Let $f(x) = 2\sin x - \cos{2x}$. Write a function `beauty_derivative_plot` that takes a point $x$ and plots the function $f(x)$ and its derivative $f'(x)$ in the range $x \in [-2\pi, 2\pi]$. The function should also plot the tangent line to the function at the point $x$.
#
# Example of output for $x = -3, -2, 1.7$:
#
# ```python
# beauty_derivative_plot(-3)
# ```
# <img src="https://github.com/V-Kisielius/StatPrak24/blob/main/imgs/tangent_line_-3.0.png?raw=true" width="600"/>
#
# ```python
# beauty_derivative_plot(-2)
# ```
# <img src="https://github.com/V-Kisielius/StatPrak24/blob/main/imgs/tangent_line_-2.0.png?raw=true" width="600"/>
#
# ```python
# beauty_derivative_plot(1.7)
# ```
# <img src="https://github.com/V-Kisielius/StatPrak24/blob/main/imgs/tangent_line_1.7.png?raw=true" width="600"/>

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return 2 * np.sin(x) - np.cos(2 * x)

def f_prime(x):
    return 2 * np.cos(x) + 2 * np.sin(2 * x)

def beauty_derivative_plot(x_point):
    x = np.linspace(-2 * np.pi, 2 * np.pi, 400)

    y = f(x)
    y_prime = f_prime(x)

    f_at_x = f(x_point)
    f_prime_at_x = f_prime(x_point)

    tangent_line = f_at_x + f_prime_at_x * (x - x_point)

    plt.figure(figsize=(10, 6))

    plt.plot(x, y, label=r'$f(x) = 2 \sin(x) - \cos(2x)$', color='blue')

    plt.plot(x, y_prime, label=r"$f ' (x) = 2\cos(x) + 2\sin(2x)$", color='green')

    plt.plot(x, tangent_line, label=f'Tangent at x = {x_point}', color='red', linestyle='--')

    plt.scatter(x_point, f_at_x, color='red', zorder=5)
    plt.text(x_point + 0.2, f_at_x, f'({x_point:.2f}, {f_at_x:.2f})', color='red')

    plt.scatter([2 * np.pi, -2 * np.pi], [f(2 * np.pi), f(-2 * np.pi)], color='black', zorder=5)

    plt.scatter([2 * np.pi, -2 * np.pi], [f_prime(2 * np.pi), f_prime(-2 * np.pi)], color='black', zorder=5)

    plt.text(2 * np.pi, -0.8, r'$2\pi$', fontsize=12, ha='center', color='black')
    plt.text(-2 * np.pi, -0.8, r'$-2\pi$', fontsize=12, ha='center', color='black')

    plt.axvline(x=2 * np.pi, color='gray', linestyle='--', alpha=0.5)
    plt.axvline(x=-2 * np.pi, color='gray', linestyle='--', alpha=0.5)

    plt.minorticks_on()
    plt.tick_params(axis='both', which='both', length=6)
    plt.tick_params(axis='both', which='minor', length=3, width=0.5)

    plt.title(r"Function $f(x)$, Function $f'(x)$ ,Tangent Line")
    plt.xlabel('x')
    plt.ylabel('y')
    plt.axhline(0, color='black',linewidth=1)
    plt.axvline(0, color='black',linewidth=1)

    plt.grid(True, which='both')

    plt.ylim(-5, np.max(y) + 1)

    plt.legend()
    plt.show()
# put here value x
beauty_derivative_plot(-3)

# %% [markdown]
# ## Problem 2

# %% [markdown]
# The data in [populations.txt](http://www.scipy-lectures.org/_downloads/populations.txt) describes the populations of hares, lynxes and carrots in northern Canada during 20 years. Get the data with
# ```python
# np.loadtxt('http://www.scipy-lectures.org/_downloads/populations.txt')
# ```
# and do the following exercises **without for-loops**.

# %% [markdown]
# - Plot the population size of each species for each year on a single graph. Add legend and axis labels to the plot.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('populations.txt', skiprows=1)


years = data[:, 0].astype(int)
hare = data[:, 1]
lynx = data[:, 2]
carrot = data[:, 3]

plt.figure(figsize=(10, 6))
plt.plot(years, hare, label="Hare", color='blue', marker='o')
plt.plot(years, lynx, label="Lynx", color='green', marker='o')
plt.plot(years, carrot, label="Carrot", color='orange', marker='o')

plt.xlabel("Year")
plt.ylabel("Population Size")
plt.title("Population Size of Hare, Lynx, and Carrot Over the Years")

plt.xticks(years, rotation=45)
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# - Find which year each species had the largest population. Mark these years in the plot of populations.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('populations.txt', skiprows=1)

years = data[:, 0].astype(int)
hare = data[:, 1]
lynx = data[:, 2]
carrot = data[:, 3]

plt.figure(figsize=(10, 6))
plt.plot(years, hare, label="Hare", color='blue', marker='o')
plt.plot(years, lynx, label="Lynx", color='green', marker='o')
plt.plot(years, carrot, label="Carrot", color='orange', marker='o')

hare_max_year = years[np.argmax(hare)]
hare_max_pop = np.max(hare)

lynx_max_year = years[np.argmax(lynx)]
lynx_max_pop = np.max(lynx)

carrot_max_year = years[np.argmax(carrot)]
carrot_max_pop = np.max(carrot)

plt.scatter(hare_max_year, hare_max_pop, color='blue', zorder=5)
plt.scatter(lynx_max_year, lynx_max_pop, color='green', zorder=5)
plt.scatter(carrot_max_year, carrot_max_pop, color='orange', zorder=5)

plt.text(hare_max_year, hare_max_pop, f'Year: {hare_max_year}\nPop: {hare_max_pop}', color='blue', ha='right')
plt.text(lynx_max_year, lynx_max_pop, f'Year: {lynx_max_year}\nPop: {lynx_max_pop}', color='green', ha='right')
plt.text(carrot_max_year, carrot_max_pop, f'Year: {carrot_max_year}\nPop: {carrot_max_pop}', color='orange', ha='right')

plt.xlabel("Year")
plt.ylabel("Population Size")
plt.title("Population Size of Hare, Lynx, and Carrot Over the Years")
plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# - Assuming total population of hares and lynxes is 100%, plot stacked bar graph showing ratio of each specis for each year in the period.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('populations.txt', skiprows=1)

years = data[:, 0]
hares = data[:, 1]
lynxes = data[:, 2]

total = hares + lynxes

hare_ratio = hares / total
lynx_ratio = lynxes / total

plt.figure(figsize=(10, 6))
plt.bar(years, hare_ratio, label="Зайцы", color='blue')
plt.bar(years, lynx_ratio, bottom=hare_ratio, label="Рыси", color='green')

plt.xlabel("Год")
plt.ylabel("Доля населения")
plt.title("Процентное соотношение зайцев и рысей по годам")
plt.legend()
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# - Find the mean and std of the populations of each species. Plot the historgam of population for each species and show mean values with vertical line. Show each histogram in a separate plot. Arrange 3 plots in a row.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('populations.txt', skiprows=1)

years   = data[:, 0]
hares   = data[:, 1]
lynxes  = data[:, 2]
carrots = data[:, 3]

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 5))

mean_hares = np.mean(hares)
std_hares  = np.std(hares)
ax1.hist(hares, bins=10, color='skyblue', edgecolor='black')
ax1.axvline(mean_hares, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_hares:.2f}')
ax1.set_title(f"Hare Population\nMean: {mean_hares:.2f}, Std: {std_hares:.2f}")
ax1.set_xlabel("Population")
ax1.set_ylabel("Frequency")
ax1.legend()

mean_lynxes = np.mean(lynxes)
std_lynxes  = np.std(lynxes)
ax2.hist(lynxes, bins=10, color='skyblue', edgecolor='black')
ax2.axvline(mean_lynxes, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_lynxes:.2f}')
ax2.set_title(f"Lynx Population\nMean: {mean_lynxes:.2f}, Std: {std_lynxes:.2f}")
ax2.set_xlabel("Population")
ax2.set_ylabel("Frequency")
ax2.legend()

mean_carrots = np.mean(carrots)
std_carrots  = np.std(carrots)
ax3.hist(carrots, bins=10, color='skyblue', edgecolor='black')
ax3.axvline(mean_carrots, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_carrots:.2f}')
ax3.set_title(f"Carrot Population\nMean: {mean_carrots:.2f}, Std: {std_carrots:.2f}")
ax3.set_xlabel("Population")
ax3.set_ylabel("Frequency")
ax3.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# - Find which species (hares or lynxes) has the largest population for each year. Print the result as [H, H, L, H, ...]. Plot a pie chart showing the ratio of "H" and "L" values.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('populations.txt', skiprows=1)

years  = data[:, 0]
hares  = data[:, 1]
lynxes = data[:, 2]

result = np.where(hares >= lynxes, "H", "L")
print(result.tolist())

unique, counts = np.unique(result, return_counts=True)

plt.figure(figsize=(6,6))
plt.pie(counts, labels=unique, autopct='%1.1f%%', colors=['blue','green'])
plt.title("Соотношение H (зайцы) и L (рыси)")
plt.show()
# Out:
# ['H', 'H', 'H', 'H', 'L', 'L', 'L', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'L', 'L', 'L', 'H', 'H', 'H']

# %% [markdown]
# - Plot the change in the hare population and in the lynx population for each year. Find the correlation coefficient between the both time series.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('populations.txt', skiprows=1)

years  = data[:, 0]
hares  = data[:, 1]
lynxes = data[:, 2]

plt.figure(figsize=(10,6))
plt.plot(years, hares, label="Зайцы", color='blue', marker='o')
plt.plot(years, lynxes, label="Рыси", color='green', marker='o')
plt.xlabel("Год")
plt.ylabel("Популяция")
plt.title("Изменение популяций зайцев и рысей по годам")
plt.legend()
plt.grid(True)
plt.show()

corr_matrix = np.corrcoef(hares, lynxes)
corr_coeff = corr_matrix[0, 1]

print("correlation coefficient between hares and lynxes :", corr_coeff)
# Out:
# correlation coefficient between hares and lynxes : 0.07189206073535571

# %% [markdown]
# - Using a scatter plot, show the population of hares vs lynxes by year (each point corresponds to a particular year, and the point coordinates correspond to the population of the two species in that year).

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('populations.txt', skiprows=1)

years = data[:, 0]
hares = data[:, 1]
lynxes = data[:, 2]

plt.figure(figsize=(8,6))
plt.scatter(hares, lynxes, color='purple', alpha=0.7, edgecolors='black')


# I didn't manage to do it without for-loops. It would be helpful if you could tell me how to do it correctly.
for i in range(len(years)):
    plt.annotate(str(int(years[i])), (hares[i], lynxes[i]), fontsize=10, ha='right')

plt.xlabel("Hare Population")
plt.ylabel("Lynx Population")
plt.title("Scatter Plot: Hare vs. Lynx Population")

plt.grid(True)

plt.show()

# %% [markdown]
# - Assume the population of hares in 1920 is unknown. Suggest a way to estimate this value. Compare an estimated value
# with the true value and print a ratio of the error to the true value.

# %%
import numpy as np

data = np.loadtxt('populations.txt', skiprows=1)

years = data[:, 0]
hares = data[:, 1]

#take data for the previous 3 years (1917, 1918, 1919)
mask = (years >= 1917) & (years < 1920)
hares_recent = hares[mask]

hare_estimated_1920 = np.mean(hares_recent)

index_1920 = np.where(years == 1920)[0][0]
hare_true_1920 = hares[index_1920]

error_ratio = abs(hare_estimated_1920 - hare_true_1920) / hare_true_1920

print(f"Estimated hare population in 1920 (mean method): {hare_estimated_1920:.2f}")
print(f"True hare population in 1920: {hare_true_1920:.2f}")
print(f"Error ratio: {error_ratio:.4f}")
# Out:
# Estimated hare population in 1920 (mean method): 12800.00
# True hare population in 1920: 24700.00
# Error ratio: 0.4818
